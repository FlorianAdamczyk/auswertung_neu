# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
def dat2array(file_path):
    data=[]
    with open(file_path, 'r', encoding='utf-8') as file: 
        
        for i,line in enumerate(file):
              a=line.replace(',','.').replace('\t', ';').replace('\n','')

              if i >= 39: data.append(a.split(';'))

    freqs = [float(val[0]) for val in data] 
    intensities = [float(val[1]) for val in data]

    return freqs,intensities

# %%
""" colors = cm.inferno(np.linspace(0.2, 0.9, 7))


peak_list,tmp_list=[],[]

for idx,i in enumerate(np.arange(300, 440, 20)): 
    freqs,intensities = dat2array(f'400uW/{i}k.asc')
    
    peak_list.append(np.max(intensities))
    tmp_list.append(i)


    plt.plot(freqs, [val/162541 for val in intensities], color=colors[idx], label=f'{i}k')

    plt.xlim(600,800)
    plt.legend(loc='upper right')
    plt.xlabel('Wavelength in nm')
    plt.ylabel('SHG intensity in a.u.') """
# Out:
# " colors = cm.inferno(np.linspace(0.2, 0.9, 7))\n\n\npeak_list,tmp_list=[],[]\n\nfor idx,i in enumerate(np.arange(300, 440, 20)): \n    freqs,intensities = dat2array(f'400uW/{i}k.asc')\n    \n    peak_list.append(np.max(intensities))\n    tmp_list.append(i)\n\n\n    plt.plot(freqs, [val/162541 for val in intensities], color=colors[idx], label=f'{i}k')\n\n    plt.xlim(600,800)\n    plt.legend(loc='upper right')\n    plt.xlabel('Wavelength in nm')\n    plt.ylabel('SHG intensity in a.u.') "

# %%
""" plt.scatter(tmp_list, peak_list)
print(np.max(peak_list)) """
# Out:
# ' plt.scatter(tmp_list, peak_list)\nprint(np.max(peak_list)) '

# %% [markdown]
# # SHG measurement of TIBI

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 15))
peak_list,tmp_list=[],[]


""" freqs_,intensities_ = dat2array(f'TIBI_400uW_1400nm/300k')
ax0.plot(freqs_, [0.1662*val/44702 for val in intensities_], color=colors[5], label=f'300K')
ax1.scatter(300,0.1662*np.max(intensities_)/44702, color=colors[5]) """





for idx,i in enumerate(np.arange(320, 440, 20)): 
    
    freqs,intensities = dat2array(f'TIBI_400uW_1400nm/{i}k')        #change path for other materials
    
    peak_list.append(np.max(intensities))
    tmp_list.append(i)

    #linker plot:
    ax0.plot(freqs, [val/44702 for val in intensities], color=colors[6+idx], label=f'{i}K')
    ax0.set_xlim(650,750)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/44702, color=colors[6+idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TIBI at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 420K )$', fontsize=18)

plt.savefig('./TIBI.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/4183031500.py:36: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TIBI at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 420K )$', fontsize=18)
# 44702.0

# %% [markdown]
# # SHG measurement of TISI

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 13))
peak_list,tmp_list=[],[]


for idx,i in enumerate(np.arange(300, 440, 20)): 
    
    freqs,intensities = dat2array(f'TISI_400uW_1400nm/{i}k')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)


    #linker plot:
    ax0.plot(freqs, [val/162541 for val in intensities], color=colors[6+idx], label=f'{i}K')
    ax0.set_xlim(650,750)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/162541, color=colors[6+idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TISI at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 420K )$', fontsize=18)

fig.savefig('./TISI.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/3777512577.py:29: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TISI at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 420K )$', fontsize=18)
# 162541.0

# %% [markdown]
# # SHG measurement of TBBB

# %% [markdown]
# ### From 290K -> 360K

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 13))
peak_list,tmp_list=[],[]


for idx,i in enumerate([290,300,320,340,360]): 
    
    freqs,intensities = dat2array(f'TBBB_400uW_1400nm/{i}k.asc')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)

    #linker plot:
    ax0.plot(freqs, [val/35927 for val in intensities], color=colors[6+idx], label=f'{i}K')
    ax0.set_xlim(650,750)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/35927, color=colors[6+idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TBBB at 1400nm and 410$\mu W ~~~ (290K \\rightarrow 360K )$', fontsize=18)

fig.savefig('./TBBB_heat.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\m'
# <>:28: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/352027207.py:28: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TBBB at 1400nm and 410$\mu W ~~~ (290K \\rightarrow 360K )$', fontsize=18)
# 35927.0

# %% [markdown]
# ### From 340K to 150K

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 13))
peak_list,tmp_list=[],[]


for idx,i in enumerate(np.arange(340,180,-20)): 
    
    freqs,intensities = dat2array(f'TBBB_400uW_1400nm/downto{i}k.asc')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)

    #linker plot:
    ax0.plot(freqs, [val/35927 for val in intensities], color=colors[9-idx], label=f'{i}K')
    ax0.set_xlim(650,750)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/35927, color=colors[9-idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TBBB at 1400nm and 410$\mu W ~~~ (340K \\rightarrow 200K )$', fontsize=18)

plt.savefig('./TBBB_cool.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\m'
# <>:28: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/2526378069.py:28: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TBBB at 1400nm and 410$\mu W ~~~ (340K \\rightarrow 200K )$', fontsize=18)
# 29585.0

# %% [markdown]
# # SHG measurement of TCBC

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 13))
peak_list,tmp_list=[],[]


for idx,i in enumerate(np.arange(300, 180, -20)): 
    
    freqs,intensities = dat2array(f'TCBC_400uW_1400nm/{i}k.asc')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)


    #linker plot:
    ax0.plot(freqs, [val/78985 for val in intensities], color=colors[6-idx], label=f'{i}K')
    ax0.set_xlim(650,750)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/78985, color=colors[6-idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TCBC at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 200K )$', fontsize=18)

fig.savefig('./TCBC.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# <>:29: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/4171151200.py:29: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TCBC at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 200K )$', fontsize=18)
# 78985.0

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 15))
shg_peak_list,thg_peak_list,tmp_list=[],[],[]


ax1.scatter([], [], color='blue', label='THG')
ax1.scatter([], [], color='green', label='SHG')



for idx,i in enumerate(np.arange(300, 480, 20)): 
    
    freqs,intensities = dat2array(f'TBBB_400uW_1400nm/hot/{i}k.asc')        #change path for other materials

    

    shg_peak_list.append(np.max(intensities[:800]))
    thg_peak_list.append(np.max(intensities[800:]))
    tmp_list.append(i)

    
    




    #linker plot:
    if i>=360: 
        ax0.plot(freqs, [2.571*val/486083 for val in intensities], color=colors[5+idx], label=f'{i}K')
    else: 
        ax0.plot(freqs, [val/486083 for val in intensities], color=colors[5+idx], label=f'{i}K')






    ax0.set_xlim(400,800)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')
    #ax0.set_yscale('log')

    #rechter plot:
    if i>=360:
        ax1.scatter(i,2.571*np.max(intensities[300:500])/486083, color='blue')
        ax1.scatter(i,2.571*np.max(intensities[700:1000])/486083, color='green')
    else:
        ax1.scatter(i,np.max(intensities[300:500])/486083, color='blue')
        ax1.scatter(i,np.max(intensities[700:1000])/486083, color='green')
        
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Normalized maximal intensity in a.u.')

ax1.legend(loc='upper left')

fig.suptitle('SHG measurement of TBBB at 1400nm and 400$\mu W ~~~ (293K \\rightarrow 460K )$', fontsize=18)

fig.savefig('./TBBB_hot.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:59: SyntaxWarning: invalid escape sequence '\m'
# <>:59: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/3879431885.py:59: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TBBB at 1400nm and 400$\mu W ~~~ (293K \\rightarrow 460K )$', fontsize=18)
# 78985.0

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 13))
peak_list,tmp_list=[],[]


ax1.scatter([], [], color='blue', label='THG')
ax1.scatter([], [], color='green', label='SHG')


for idx,i in enumerate([80,100,120,140,160,180,200,240,290]): 
    
    freqs,intensities = dat2array(f'TBBB_400uW_1400nm/cold/{i}k.asc')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)


    #linker plot:
    ax0.plot(freqs, [val/22870 for val in intensities], color=colors[idx], label=f'{i}K')
    ax0.set_xlim(400,800)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')
    #ax0.set_yscale('log')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/22870, color='blue')
    ax1.scatter(i,np.max(intensities[600:1000])/22870, color='green')
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal intensity in a.u.')

ax1.legend(loc='upper right')

fig.suptitle('SHG measurement of TBBB at 1400nm and 400$\mu W ~~~ (80K \\rightarrow 290K )$', fontsize=18)

fig.savefig('./TBBB_cold.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# <>:36: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/3604401138.py:36: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TBBB at 1400nm and 400$\mu W ~~~ (80K \\rightarrow 290K )$', fontsize=18)
# 22870.0

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(15, 5))  


colors = cm.plasma(np.linspace(0, 1, 15))
peak_list,tmp_list=[],[]


for idx,i in enumerate(np.arange(300,480,20)): 
    
    freqs,intensities = dat2array(f'TCBC_400uW_1400nm/hot/{i}k.asc')        #change path for other materials

    peak_list.append(np.max(intensities))
    tmp_list.append(i)


    #linker plot:
    ax0.plot(freqs, [val/69343 for val in intensities], color=colors[5+idx], label=f'{i}K')
    ax0.set_xlim(670,740)
    ax0.legend(loc='upper right')
    ax0.set_xlabel('Wavelength in nm')
    ax0.set_ylabel('SHG intensity in a.u.')
    #ax0.set_yscale('log')

    #rechter plot:
    ax1.scatter(i,np.max(intensities)/69343, color=colors[5+idx])
    ax1.set_xlabel('Temperature in K')
    ax1.set_ylabel('Maximal SHG intensity in a.u.')


fig.suptitle('SHG measurement of TCBC at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 460K )$', fontsize=18)

fig.savefig('./TCBC_hot.png', dpi=600)

print(np.max(peak_list))
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# <>:30: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_101040/1376467613.py:30: SyntaxWarning: invalid escape sequence '\m'
#   fig.suptitle('SHG measurement of TCBC at 1400nm and 400$\mu W ~~~ (300K \\rightarrow 460K )$', fontsize=18)
# 69343.0

# %%
for i in np.arange(300,480,20): print(i)
# Out:
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
